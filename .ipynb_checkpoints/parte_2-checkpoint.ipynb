# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt

# %%
def reta(dados_x, dados_y, titulo, label_x, label_y):    
    a = dados_y.cov(dados_x) / dados_x.var()
    b = dados_y.mean() - a*dados_x.mean()
 
 
    fig = plt.figure(figsize=(8, 6))
    plt.scatter(dados_x, dados_y, c='red', alpha=0.8)
    plt.title(titulo)
    plt.xlabel(label_x)
    plt.ylabel(label_y)
 
    plt.plot((dados_x.min(), dados_x.max()), (a*dados_x.min()+b, a*dados_x.max()+b), color='blue')
 
    plt.tight_layout()
    plt.show()

# %%
def ab(dados_x, dados_y):    
    a = dados_y.cov(dados_x) / dados_x.var()
    b = dados_y.mean() - a*dados_x.mean()
    return a, b

# %%
def tudo(anoI, anoF, nomeX, nomeY, data_set, titulo, label_x, label_y):
    lista = np.arange(anoI, anoF+1)
    fig = plt.figure(figsize=(20, 15))
    for d in lista:
        
        dados_x = data_set[nomeX + str(d)]
        dados_y = data_set[nomeY + str(d)]
       
        a = dados_y.cov(dados_x) / dados_x.var()
        b = dados_y.mean() - a*dados_x.mean()
 
        plt.scatter(dados_x, dados_y, alpha=0.8)
        plt.plot((dados_x.min(), dados_x.max()), (a*dados_x.min()+b, a*dados_x.max()+b))
    
    plt.tight_layout()
    plt.title(titulo)
    plt.xlabel(label_x)
    plt.ylabel(label_y)
    plt.show()

# %%
#Leitura dos arquivos em Excel
data = pd.read_excel('data.xlsx')

# %%
#Mudança de index
data_idx = data.set_index('Country')

# %%
reta(data["HDI in 2015"], data["Tech exports in 2015"], "X", "IDH", "Tech Exports")
# Out:
# Ajuste linear entre X3 e X4:
# Coeficiente linear: -12.484286526831918
# Coeficiente angular: 30.62550700802697

# %%
reta(data["HDI in 2015"], data["Internet users in 2015"], "X", "IDH", "Internet")
# Out:
# Ajuste linear entre X3 e X4:
# Coeficiente linear: -82.59741101355499
# Coeficiente angular: 169.45902727126727

# %%
Z = ab(data["HDI in 2010"], data["Internet users in 2010"])
print(Z[0], Z[1])
# Out:
# 169.45902727126727 -82.59741101355499

# %%
tudo(2001, 2015, "HDI in ", "Internet users in ", data, "G", "X", "Y")
