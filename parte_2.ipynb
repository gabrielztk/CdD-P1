# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt
from funcs import *

# %%
#Leitura dos arquivos em Excel
data = pd.read_excel('data.xlsx')

# %%
#Mudança de index
data_idx = data.set_index('Country')

# %% [markdown]
# # fdagdgsda

# %%
reta(data["HDI in 2015"], data["Tech exports in 2015"], "X", "IDH", "Tech Exports")
# Out:
# Taxa de correlaçâo: 0.4177
# Coeficiente angular da reta: 30.6255

# %% [markdown]
# # dfsdfsdf

# %%
data["Tech exports in 2015"].plot.hist(density=True)

# %% [markdown]
# # dgfgdfg

# %%
box(data["Tech exports in 2015"])
# Out:
# A mediana desta seleção de dados é: 7.1500%
# A média desta seleção de dados é: 10.4744%

# %% [markdown]
# # dsfsfdsfsf

# %%
reta(data["HDI in 2015"], data["Internet users in 2015"], "X", "IDH", "Internet")
# Out:
# Taxa de correlaçâo: 0.9257
# Coeficiente angular da reta: 169.7975

# %% [markdown]
# # dfgdfgdfg

# %%
data["Internet users in 2015"].plot.hist(density=True)

# %% [markdown]
# # sdfsdf

# %%
box(data["Internet users in 2015"])
# Out:
# A mediana desta seleção de dados é: 58.3000%
# A média desta seleção de dados é: 55.8827%

# %% [markdown]
# # dsfsdfsfs

# %%
tudo(2001, 2015, "HDI in ", "Internet users in ", data, "G", "IDH", "Internet")
# Out:
# Taxa de correlaçâo em 2001: 0.7269
# Coeficiente angular da reta em 2001: 78.0780
#
# Taxa de correlaçâo em 2002: 0.7409
# Coeficiente angular da reta em 2002: 98.6702
#
# Taxa de correlaçâo em 2003: 0.7604
# Coeficiente angular da reta em 2003: 111.3620
#
# Taxa de correlaçâo em 2004: 0.7700
# Coeficiente angular da reta em 2004: 121.3603
#
# Taxa de correlaçâo em 2005: 0.7802
# Coeficiente angular da reta em 2005: 129.2525
#
# Taxa de correlaçâo em 2006: 0.8022
# Coeficiente angular da reta em 2006: 138.4157
#
# Taxa de correlaçâo em 2007: 0.8300
# Coeficiente angular da reta em 2007: 149.0636
#
# Taxa de correlaçâo em 2008: 0.8446
# Coeficiente angular da reta em 2008: 157.4508
#
# Taxa de correlaçâo em 2009: 0.8644
# Coeficiente angular da reta em 2009: 165.2878
#
# Taxa de correlaçâo em 2010: 0.8848
# Coeficiente angular da reta em 2010: 169.4590
#
# Taxa de correlaçâo em 2011: 0.9046
# Coeficiente angular da reta em 2011: 173.4290
#
# Taxa de correlaçâo em 2012: 0.9094
# ...

# %%
caca(2001, 2015, "HDI in ", "Tech exports in ", data)
# Out:
# Taxa de correlaçâo em 2001: 0.4020
#
# Taxa de correlaçâo em 2002: 0.3500
#
# Taxa de correlaçâo em 2003: 0.3502
#
# Taxa de correlaçâo em 2004: 0.3323
#
# Taxa de correlaçâo em 2005: 0.3450
#
# Taxa de correlaçâo em 2006: 0.3374
#
# Taxa de correlaçâo em 2007: 0.3242
#
# Taxa de correlaçâo em 2008: 0.3767
#
# Taxa de correlaçâo em 2009: 0.3359
#
# Taxa de correlaçâo em 2010: 0.4133
#
# Taxa de correlaçâo em 2011: 0.2908
#
# Taxa de correlaçâo em 2012: 0.3262
#
# Taxa de correlaçâo em 2013: 0.2726
#
# Taxa de correlaçâo em 2014: 0.2640
#
# Taxa de correlaçâo em 2015: 0.4177
